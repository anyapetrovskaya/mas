# %% [markdown]
# <a href="https://colab.research.google.com/github/anyapetrovskaya/mas/blob/main/My_First_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Hello World

# %% [markdown]
# let's start with some basics

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# Initialization. Mount the drive and load libs.

# %%
import os, sys
from pathlib import Path
from google.colab import drive

# mount google drive
drive_path = '/content/drive'
if not Path(drive_path).exists(): drive.mount(drive_path)

# setup shortcuts
co_path = '/content/Colab'
lib_path = co_path + '/libs'
nb_path = co_path + '/notebooks'
own_path = co_path + '/own'
third_path = co_path + '/thirdParty'
if not Path(co_path).exists(): 
  os.symlink(drive_path + '/My Drive/Colab', co_path)

# update module path
if lib_path not in sys.path: sys.path.insert(0,lib_path)
if third_path not in sys.path: sys.path.insert(0,third_path)
if own_path not in sys.path: sys.path.insert(0,own_path)

# import own modules
import importlib
import myHello
importlib.reload(myHello)
myHello.helloWorld()
# Out:
# Mounted at /content/drive
# hello from helloWorld module

# %% [markdown]
# Install additional modules as needed

# %%
# !ls Colab/
# to install more modules run
#!pip install --target=$lib_path jdc
# Out:
# libs  notebooks  own

# %%
import numpy as np
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

plt.figure(facecolor='grey')
ax = plt.axes()
ax.set_facecolor('grey')
plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)

plt.title("Sample Visualization")
plt.show()
